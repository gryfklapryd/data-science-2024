# %% [markdown]
# <a href="https://colab.research.google.com/github/gryfklapryd/data-science-2024/blob/main/Pertemuan1_Greyfikal_Apriyuda_250401020064.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama Lengkap: Greyfikal Apriyuda <br>
# NIM: 250401020064 <br>
# Kelas: Data Science IF401

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
nama = "Greyfikal Apriyuda"
angkatan = 2025
ipk = 3.86
aktif = True

print(f"Nama : {nama}")
print(f"Angkatan : {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Greyfikal Apriyuda
# Angkatan : 2025
# IPK : 3.86
# Aktif : True

# %%
tools = ["python", "google colab", "jupyter notebook", "github"]
print("\nTools data science yang akan kita pelajari: ")
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")
# Out:
# Tools data science yang akan kita pelajari:
#  1. python
#  2. google colab
#  3. jupyter notebook
#  4. github

# %%
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Greyfikal Apriyuda", "Informatika", 2025)
print(hasil)
# Out:
# Hai! Saya Greyfikal Apriyuda dari Informatika, angkatan 2025.

# %% [markdown]
# Apa yang dipelajari: Dasar-dasar sintaks Python yaitu meliputi fungsi print(), deklarasi variabel dengan tipe data (string, int, float, boolean), penggunaan f-string untuk formatting teks serta iterasi<br>
# Temuan utama: Penulisan kode Python sangat ringkas dan mudah dibaca. Penggunaan f-string jauh lebih praktis untuk menggabungkan teks dengan variabel. Selain itu, fungsi bawaan enumerate bikin pembuatan list bernomor dalam looping jadi sangat efisien karena tidak perlu membuat variabel counter manual.<br>
# Pertanyaan yang muncul: Belum ada pertanyaan yang muncul<br>
